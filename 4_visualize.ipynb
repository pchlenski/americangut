# %%
# !pip install plotly
# !pip install ipywidgets
# Out:
# Requirement already satisfied: plotly in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from plotly) (8.2.2)
# Requirement already satisfied: packaging in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from plotly) (23.1)
# Requirement already satisfied: ipywidgets in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (8.0.7)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipywidgets) (6.24.0)
# Requirement already satisfied: ipython>=6.1.0 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipywidgets) (8.14.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipywidgets) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipywidgets) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipywidgets) (3.0.8)
# Requirement already satisfied: comm>=0.1.1 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.3)
# Requirement already satisfied: debugpy>=1.6.5 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (8.3.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.3.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (1.5.6)
# Requirement already satisfied: packaging in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (23.1)
# Requirement already satisfied: psutil in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.5)
# Requirement already satisfied: pyzmq>=20 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipykernel>=4.5.1->ipywidgets) (6.3.2)
# Requirement already satisfied: backcall in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.0)
# Requirement already satisfied: decorator in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.18.2)
# Requirement already satisfied: pickleshare in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (2.15.1)
# Requirement already satisfied: stack-data in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets) (3.8.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets) (0.2.6)
# Requirement already satisfied: executing>=1.2.0 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: pure-eval in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from stack-data->ipython>=6.1.0->ipywidgets) (0.2.2)
# Requirement already satisfied: six in /home/phil/mambaforge/envs/americangut/lib/python3.11/site-packages (from asttokens>=2.1.0->stack-data->ipython>=6.1.0->ipywidgets) (1.16.0)

# %%
import plotly
import anndata

import pandas as pd
import plotly.graph_objects as go
import ipywidgets as widgets
from IPython.display import display
import numpy as np

plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.24.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# adata = anndata.read_h5ad("data/big_table_with_embeddings_1000.h5ad")
# adata = anndata.read_h5ad("data/americangut_embeddings.h5ad")
# adata = anndata.read_h5ad("data/delete/big_table_with_embeddings_full.h5ad")
adata = anndata.read_h5ad("data/big_table_with_embeddings.h5ad")

# %%
nan_vals = [np.nan, np.inf, -np.inf, "nan", "n/a", "na"]

# %%
# Add F:B ratio

f_cols = adata.var[adata.var["taxonomy_1"] == "p__Firmicutes"].index
b_cols = adata.var[adata.var["taxonomy_1"] == "p__Bacteroidetes"].index

f_vals = adata[:, f_cols].X.sum(axis=1)
b_vals = adata[:, b_cols].X.sum(axis=1) + 1e-6

fb_ratio = f_vals / b_vals
adata.obs["fb_ratio"] = np.clip(fb_ratio, 0, 10)

# %%
# Drop boring columns
for col in reversed(adata.obs.columns):
    vals = adata.obs[col]
    if vals.dtype.name == "category":
        vals = vals.str.lower()
        nan_indicator = vals.isin(nan_vals)
        n_nans = nan_indicator.sum()
        vals_filtered = vals[~nan_indicator]
    else:
        nan_indicator = np.isnan(vals)
        n_nans = nan_indicator.sum()
    if n_nans > 20000:
        print(f"Dropping {col} with {n_nans} nan values")
        adata.obs.drop(columns=col, inplace=True)

    elif vals[~nan_indicator].nunique() == 1:
        print(f"Dropping {col} with only one unique value")
        adata.obs.drop(columns=col, inplace=True)
# Out:
# Dropping weight_units with 32608 nan values
# Dropping weight_kg with 32608 nan values
# Dropping weight_cat with 32589 nan values
# Dropping weekend_wake_time with 32608 nan values
# Dropping weekend_sleep_time with 32608 nan values
# Dropping weekday_wake_time with 32608 nan values
# Dropping weekday_sleep_time with 32608 nan values
# Dropping vioscreen_zinc with 32601 nan values
# Dropping vioscreen_xylitol with 32601 nan values
# Dropping vioscreen_whole_grain_servings with 32601 nan values
# Dropping vioscreen_wgrain with 32601 nan values
# Dropping vioscreen_weight with 32608 nan values
# Dropping vioscreen_water with 32601 nan values
# Dropping vioscreen_vitk with 32601 nan values
# Dropping vioscreen_vite_iu with 32601 nan values
# Dropping vioscreen_vitd_iu with 32601 nan values
# Dropping vioscreen_vitd3 with 32601 nan values
# Dropping vioscreen_vitd2 with 32601 nan values
# Dropping vioscreen_vitd with 32601 nan values
# Dropping vioscreen_vitc with 32601 nan values
# Dropping vioscreen_vitb6 with 32601 nan values
# Dropping vioscreen_vitb12 with 32601 nan values
# Dropping vioscreen_vita_re with 32601 nan values
# Dropping vioscreen_vita_rae with 32601 nan values
# Dropping vioscreen_vita_iu with 32601 nan values
# Dropping vioscreen_visit with 32608 nan values
# Dropping vioscreen_vegsumm with 32601 nan values
# Dropping vioscreen_vegetable_servings with 32601 nan values
# Dropping vioscreen_veg5_day with 32601 nan values
# Dropping vioscreen_valine with 32601 nan values
# Dropping vioscreen_v_total with 32601 nan values
# Dropping vioscreen_v_tomato with 32601 nan values
# Dropping vioscreen_v_starcy with 32601 nan values
# Dropping vioscreen_v_potato with 32601 nan values
# Dropping vioscreen_v_other with 32601 nan values
# Dropping vioscreen_v_orange with 32601 nan values
# Dropping vioscreen_v_drkgr with 32601 nan values
# Dropping vioscreen_user_id with 32608 nan values
# Dropping vioscreen_tyrosine with 32601 nan values
# Dropping vioscreen_tryptoph with 32601 nan values
# Dropping vioscreen_totsugar with 32601 nan values
# Dropping vioscreen_totfolat with 32601 nan values
# Dropping vioscreen_totcla with 32601 nan values
# Dropping vioscreen_totaltfa with 32601 nan values
# Dropping vioscreen_time with 32608 nan values
# Dropping vioscreen_threonin with 32601 nan values
# Dropping vioscreen_thiamin with 32601 nan values
# Dropping vioscreen_tgrain with 32601 nan values
# Dropping vioscreen_tfa182t with 32601 nan values
# Dropping vioscreen_tfa181t with 32601 nan values
# Dropping vioscreen_tfa161t with 32601 nan values
# Dropping vioscreen_tagatose with 32601 nan values
# Dropping vioscreen_sweet_servings with 32601 nan values
# Dropping vioscreen_sucrose with 32601 nan values
# Dropping vioscreen_sucrlose with 32601 nan values
# Dropping vioscreen_sucpoly with 32601 nan values
# Dropping vioscreen_subject_id with 32608 nan values
# Dropping vioscreen_started with 32608 nan values
# Dropping vioscreen_starch with 32601 nan values
# Dropping vioscreen_srvid with 32608 nan values
# Dropping vioscreen_sorbitol with 32601 nan values
# Dropping vioscreen_sodium with 32601 nan values
# Dropping vioscreen_sfatot with 32601 nan values
# Dropping vioscreen_sfa80 with 32601 nan values
# Dropping vioscreen_sfa60 with 32601 nan values
# Dropping vioscreen_sfa40 with 32601 nan values
# Dropping vioscreen_sfa220 with 32601 nan values
# Dropping vioscreen_sfa200 with 32601 nan values
# Dropping vioscreen_sfa180 with 32601 nan values
# Dropping vioscreen_sfa170 with 32601 nan values
# Dropping vioscreen_sfa160 with 32601 nan values
# Dropping vioscreen_sfa140 with 32601 nan values
# Dropping vioscreen_sfa120 with 32601 nan values
# Dropping vioscreen_sfa100 with 32601 nan values
# Dropping vioscreen_serine with 32601 nan values
# Dropping vioscreen_selenium with 32601 nan values
# Dropping vioscreen_scfv with 32608 nan values
# Dropping vioscreen_scf with 32608 nan values
# Dropping vioscreen_satoco with 32601 nan values
# Dropping vioscreen_salad_vegetable_servings with 32601 nan values
# Dropping vioscreen_sacchar with 32601 nan values
# Dropping vioscreen_ribofla with 32601 nan values
# Dropping vioscreen_rgrain with 32601 nan values
# Dropping vioscreen_retinol with 32601 nan values
# Dropping vioscreen_recno with 32608 nan values
# Dropping vioscreen_questionnaire with 32601 nan values
# Dropping vioscreen_protveg with 32601 nan values
# Dropping vioscreen_protocol with 32608 nan values
# Dropping vioscreen_protein with 32601 nan values
# Dropping vioscreen_protanim with 32601 nan values
# Dropping vioscreen_proline with 32601 nan values
# Dropping vioscreen_procdate with 32608 nan values
# Dropping vioscreen_potass with 32601 nan values
# Dropping vioscreen_pinitol with 32601 nan values
# Dropping vioscreen_phytic with 32601 nan values
# Dropping vioscreen_phosphor with 32601 nan values
# Dropping vioscreen_phenylal with 32601 nan values
# Dropping vioscreen_pfatot with 32601 nan values
# Dropping vioscreen_pfa226 with 32601 nan values
# Dropping vioscreen_pfa225 with 32601 nan values
# Dropping vioscreen_pfa205 with 32601 nan values
# Dropping vioscreen_pfa204 with 32601 nan values
# Dropping vioscreen_pfa184 with 32601 nan values
# Dropping vioscreen_pfa183 with 32601 nan values
# Dropping vioscreen_pfa182 with 32601 nan values
# Dropping vioscreen_pectins with 32601 nan values
# Dropping vioscreen_pantothe with 32601 nan values
# Dropping vioscreen_oxalicm with 32601 nan values
# Dropping vioscreen_oxalic with 32601 nan values
# Dropping vioscreen_omega3 with 32601 nan values
# Dropping vioscreen_nutrient_recommendation with 32608 nan values
# Dropping vioscreen_non_fried_fish_servings with 32601 nan values
# Dropping vioscreen_nitrogen with 32601 nan values
# Dropping vioscreen_niacineq with 32601 nan values
# Dropping vioscreen_niacin with 32601 nan values
# Dropping vioscreen_nccglgr with 32601 nan values
# Dropping vioscreen_nccglbr with 32601 nan values
# Dropping vioscreen_natoco with 32601 nan values
# Dropping vioscreen_multivitamin_freq with 32601 nan values
# Dropping vioscreen_multivitamin with 32601 nan values
# Dropping vioscreen_multi_calcium_dose with 32601 nan values
# Dropping vioscreen_multi_calcium_avg with 32601 nan values
# Dropping vioscreen_mfatot with 32601 nan values
# Dropping vioscreen_mfa221 with 32601 nan values
# Dropping vioscreen_mfa201 with 32601 nan values
# Dropping vioscreen_mfa181 with 32601 nan values
# Dropping vioscreen_mfa161 with 32601 nan values
# Dropping vioscreen_mfa141 with 32601 nan values
# Dropping vioscreen_methion with 32601 nan values
# Dropping vioscreen_methhis3 with 32601 nan values
# Dropping vioscreen_mannitol with 32601 nan values
# Dropping vioscreen_mangan with 32601 nan values
# Dropping vioscreen_maltose with 32601 nan values
# Dropping vioscreen_maltitol with 32601 nan values
# Dropping vioscreen_magnes with 32601 nan values
# Dropping vioscreen_m_soy with 32601 nan values
# Dropping vioscreen_m_poult with 32601 nan values
# Dropping vioscreen_m_organ with 32601 nan values
# Dropping vioscreen_m_nutsd with 32601 nan values
# Dropping vioscreen_m_mpf with 32601 nan values
# Dropping vioscreen_m_meat with 32601 nan values
# Dropping vioscreen_m_frank with 32601 nan values
# Dropping vioscreen_m_fish_lo with 32601 nan values
# Dropping vioscreen_m_fish_hi with 32601 nan values
# Dropping vioscreen_m_egg with 32601 nan values
# Dropping vioscreen_lysine with 32601 nan values
# Dropping vioscreen_lycopene with 32601 nan values
# Dropping vioscreen_lutzeax with 32601 nan values
# Dropping vioscreen_low_fat_dairy_serving with 32601 nan values
# Dropping vioscreen_line_gi with 32601 nan values
# Dropping vioscreen_leucine with 32601 nan values
# Dropping vioscreen_legumes with 32601 nan values
# Dropping vioscreen_lactose with 32601 nan values
# Dropping vioscreen_lactitol with 32601 nan values
# Dropping vioscreen_juice_servings with 32601 nan values
# Dropping vioscreen_joules with 32601 nan values
# Dropping vioscreen_isomalt with 32601 nan values
# Dropping vioscreen_isoleuc with 32601 nan values
# Dropping vioscreen_iron with 32601 nan values
# Dropping vioscreen_inositol with 32601 nan values
# Dropping vioscreen_histidin with 32601 nan values
# Dropping vioscreen_height with 32608 nan values
# Dropping vioscreen_hei_whl_grains with 32601 nan values
# Dropping vioscreen_hei_veg with 32601 nan values
# Dropping vioscreen_hei_sol_fat_alc_add_sug with 32601 nan values
# Dropping vioscreen_hei_sodium with 32601 nan values
# Dropping vioscreen_hei_score with 32601 nan values
# Dropping vioscreen_hei_sat_fat with 32601 nan values
# Dropping vioscreen_hei_oils with 32601 nan values
# Dropping vioscreen_hei_non_juice_frt with 32601 nan values
# Dropping vioscreen_hei_milk with 32601 nan values
# Dropping vioscreen_hei_meat_beans with 32601 nan values
# Dropping vioscreen_hei_grains with 32601 nan values
# Dropping vioscreen_hei_fruit with 32601 nan values
# Dropping vioscreen_hei_drk_g_org_veg_leg with 32601 nan values
# Dropping vioscreen_hei2010_whole_grains with 32601 nan values
# Dropping vioscreen_hei2010_whole_fruit with 32601 nan values
# Dropping vioscreen_hei2010_veg with 32601 nan values
# Dropping vioscreen_hei2010_sodium with 32601 nan values
# Dropping vioscreen_hei2010_sea_foods_plant_protiens with 32601 nan values
# Dropping vioscreen_hei2010_score with 32601 nan values
# Dropping vioscreen_hei2010_refined_grains with 32601 nan values
# Dropping vioscreen_hei2010_protien_foods with 32601 nan values
# Dropping vioscreen_hei2010_greens_beans with 32601 nan values
# Dropping vioscreen_hei2010_fruit with 32601 nan values
# Dropping vioscreen_hei2010_fatty_acids with 32601 nan values
# Dropping vioscreen_hei2010_empty_calories with 32601 nan values
# Dropping vioscreen_hei2010_dairy with 32601 nan values
# Dropping vioscreen_grams with 32601 nan values
# Dropping vioscreen_glycitn with 32601 nan values
# Dropping vioscreen_glycine with 32601 nan values
# Dropping vioscreen_glutamic with 32601 nan values
# Dropping vioscreen_glucose with 32601 nan values
# Dropping vioscreen_gltc with 32601 nan values
# Dropping vioscreen_glac with 32601 nan values
# Dropping vioscreen_genistn with 32601 nan values
# Dropping vioscreen_gender with 32608 nan values
# Dropping vioscreen_gammtoco with 32601 nan values
# Dropping vioscreen_galactos with 32601 nan values
# Dropping vioscreen_g_whl with 32601 nan values
# Dropping vioscreen_g_total with 32601 nan values
# Dropping vioscreen_g_nwhl with 32601 nan values
# Dropping vioscreen_fruit_servings with 32601 nan values
# Dropping vioscreen_fructose with 32601 nan values
# Dropping vioscreen_frtsumm with 32601 nan values
# Dropping vioscreen_frt5_day with 32601 nan values
# Dropping vioscreen_fried_food_servings with 32601 nan values
# Dropping vioscreen_fried_fish_servings with 32601 nan values
# Dropping vioscreen_formontn with 32601 nan values
# Dropping vioscreen_fol_syn with 32601 nan values
# Dropping vioscreen_fol_nat with 32601 nan values
# Dropping vioscreen_fol_deqv with 32601 nan values
# Dropping vioscreen_fish_servings with 32601 nan values
# Dropping vioscreen_finished with 32608 nan values
# Dropping vioscreen_fibinso with 32601 nan values
# Dropping vioscreen_fibh2o with 32601 nan values
# Dropping vioscreen_fiber with 32601 nan values
# Dropping vioscreen_fat with 32601 nan values
# Dropping vioscreen_f_total with 32601 nan values
# Dropping vioscreen_f_other with 32601 nan values
# Dropping vioscreen_f_nj_total with 32601 nan values
# Dropping vioscreen_f_nj_other with 32601 nan values
# Dropping vioscreen_f_nj_citmlb with 32601 nan values
# Dropping vioscreen_f_citmlb with 32601 nan values
# Dropping vioscreen_erythr with 32601 nan values
# Dropping vioscreen_email with 32608 nan values
# Dropping vioscreen_eer with 32608 nan values
# Dropping vioscreen_dob with 32608 nan values
# Dropping vioscreen_discfat_sol with 32601 nan values
# Dropping vioscreen_discfat_oil with 32601 nan values
# Dropping vioscreen_delttoco with 32601 nan values
# Dropping vioscreen_database with 32601 nan values
# Dropping vioscreen_daidzein with 32601 nan values
# Dropping vioscreen_d_yogurt with 32601 nan values
# Dropping vioscreen_d_total with 32601 nan values
# Dropping vioscreen_d_tot_soym with 32601 nan values
# Dropping vioscreen_d_milk with 32601 nan values
# Dropping vioscreen_d_cheese with 32601 nan values
# Dropping vioscreen_cystine with 32601 nan values
# Dropping vioscreen_coumest with 32601 nan values
# Dropping vioscreen_copper with 32601 nan values
# Dropping vioscreen_clat10c12 with 32601 nan values
# Dropping vioscreen_clac9t11 with 32601 nan values
# Dropping vioscreen_choline with 32601 nan values
# Dropping vioscreen_cholest with 32601 nan values
# Dropping vioscreen_carbo with 32601 nan values
# Dropping vioscreen_calories with 32601 nan values
# Dropping vioscreen_calcium_servings with 32601 nan values
# Dropping vioscreen_calcium_from_dairy_servings with 32601 nan values
# Dropping vioscreen_calcium_freq with 32601 nan values
# Dropping vioscreen_calcium_dose with 32601 nan values
# Dropping vioscreen_calcium_avg with 32601 nan values
# Dropping vioscreen_calcium with 32601 nan values
# Dropping vioscreen_caffeine with 32601 nan values
# Dropping vioscreen_bmi with 32608 nan values
# Dropping vioscreen_biochana with 32601 nan values
# Dropping vioscreen_betatoco with 32601 nan values
# Dropping vioscreen_betaine with 32601 nan values
# Dropping vioscreen_betacryp with 32601 nan values
# Dropping vioscreen_betacar with 32601 nan values
# Dropping vioscreen_bcodeid with 32608 nan values
# Dropping vioscreen_avcarb with 32601 nan values
# Dropping vioscreen_aspartic with 32601 nan values
# Dropping vioscreen_aspartam with 32601 nan values
# Dropping vioscreen_ash with 32601 nan values
# Dropping vioscreen_arginine with 32601 nan values
# Dropping vioscreen_alphtoco with 32601 nan values
# Dropping vioscreen_alphtoce with 32601 nan values
# Dropping vioscreen_alphacar with 32601 nan values
# Dropping vioscreen_alcohol_servings with 32601 nan values
# Dropping vioscreen_alcohol with 32601 nan values
# Dropping vioscreen_alanine with 32601 nan values
# Dropping vioscreen_age with 32608 nan values
# Dropping vioscreen_adsugtot with 32601 nan values
# Dropping vioscreen_addsugar with 32601 nan values
# Dropping vioscreen_add_sug with 32601 nan values
# Dropping vioscreen_activity_level with 32608 nan values
# Dropping vioscreen_acesupot with 32601 nan values
# Dropping vioscreen_a_cal with 32601 nan values
# Dropping vioscreen_a_bev with 32601 nan values
# Dropping toilet_water_access with 32589 nan values
# Dropping thdmi_cohort with 31072 nan values
# Dropping surf_weetsuit with 32129 nan values
# Dropping surf_wax with 32141 nan values
# Dropping surf_travel_frequency with 32191 nan values
# Dropping surf_travel_distance with 32140 nan values
# Dropping surf_sunscreen_frequency with 32138 nan values
# Dropping surf_sunscreen with 32214 nan values
# Dropping surf_stance with 32135 nan values
# Dropping surf_shower_frequency with 32130 nan values
# Dropping surf_local_break with 32115 nan values
# Dropping surf_loal_break_frequency with 32127 nan values
# Dropping surf_frequency with 32129 nan values
# Dropping surf_board_type with 32135 nan values
# Dropping subset_ibd with 32542 nan values
# Dropping subset_healthy with 32542 nan values
# Dropping subset_diabetes with 32542 nan values
# Dropping subset_bmi with 32542 nan values
# Dropping subset_antibiotic_history with 32542 nan values
# Dropping subset_age with 32542 nan values
# Dropping state with 32270 nan values
# Dropping sleep_quality with 32608 nan values
# Dropping setting with 32589 nan values
# Dropping qiita_study_id with only one unique value
# Dropping public with only one unique value
# Dropping pm_useful with 32608 nan values
# Dropping pm_understand_results with 32608 nan values
# Dropping pm_shared_who_unspecified with 32608 nan values
# Dropping pm_shared_who_specialty_physician_eg_gastroenterologist with 32608 nan values
# Dropping pm_shared_who_primary_care_physician with 32608 nan values
# Dropping pm_shared_who_posteddiscussed_on_social_networking_site_ie_facebook with 32608 nan values
# Dropping pm_shared_who_posteddiscussed_on_data_sharing_platform_ie_open_humans with 32608 nan values
# Dropping pm_shared_who_posteddiscussed_on_an_online_patienthealth_platform_ie_patientslikeme with 32608 nan values
# Dropping pm_shared_who_other_medical_or_health_professional with 32608 nan values
# Dropping pm_shared_who_other with 32608 nan values
# Dropping pm_shared_who_nutritionistdietician with 32608 nan values
# Dropping pm_shared_who_friends with 32608 nan values
# Dropping pm_shared_who_family_members with 32608 nan values
# Dropping pm_shared_who_colleagues with 32608 nan values
# Dropping pm_shared_who with 32608 nan values
# Dropping pm_shared_pcp_changes_what_unspecified with 32608 nan values
# Dropping pm_shared_pcp_changes_what_referral_to_a_specialist_eg_gastroenterologist with 32608 nan values
# Dropping pm_shared_pcp_changes_what_other with 32608 nan values
# Dropping pm_shared_pcp_changes_what_ordered_additional_labs_tests_or_procedures with 32608 nan values
# Dropping pm_shared_pcp_changes_what_change_in_medication_ie_starting_stopping_or_changing_the_dose_of_a_prescription with 32608 nan values
# Dropping pm_shared_pcp_changes_what_change_in_behaviorallifestyle_recommendations_eg_start_probiotic with 32608 nan values
# Dropping pm_shared_pcp_changes_what with 32608 nan values
# Dropping pm_shared_pcp_changes with 32608 nan values
# Dropping pm_shared_pcp with 32608 nan values
# Dropping pm_shared with 32608 nan values
# Dropping pm_recontact with 32608 nan values
# Dropping pm_participation_reason_unspecified with 32608 nan values
# Dropping pm_participation_reason_the_study_seemed_fun_and_entertaining with 32608 nan values
# Dropping pm_participation_reason_professional_interest_in_the_microbiome with 32608 nan values
# Dropping pm_participation_reason_people_in_my_family_or_social_network_have_done_it with 32608 nan values
# Dropping pm_participation_reason_other with 32608 nan values
# Dropping pm_participation_reason_interest_in_contributing_to_science with 32608 nan values
# Dropping pm_participation_reason_i_have_other_microbiomerelevant_health_problems with 32608 nan values
# Dropping pm_participation_reason_i_have_gastrointestinal_problems with 32608 nan values
# Dropping pm_participation_reason_general_curiosityinterest_in_learning_about_my_microbiome with 32608 nan values
# Dropping pm_participation_reason_desire_to_improve_my_health with 32608 nan values
# Dropping pm_participation_reason with 32608 nan values
# Dropping pm_name with 32608 nan values
# Dropping pm_lifestyle_change_how_unspecified with 32608 nan values
# Dropping pm_lifestyle_change_how_other with 32608 nan values
# Dropping pm_lifestyle_change_how_change_in_use_of_nutritional_supplements_or_vitamins with 32608 nan values
# Dropping pm_lifestyle_change_how_change_in_physical_environment_ie_adopting_or_getting_rid_of_a_pet_cleaning_more_or_less_often with 32608 nan values
# Dropping pm_lifestyle_change_how_change_in_exercise with 32608 nan values
# Dropping pm_lifestyle_change_how_change_in_diet_ie_taking_a_probiotic with 32608 nan values
# Dropping pm_lifestyle_change_how_change_in_alcohol_or_tobacco_use_ie_starting_stopping_or_changing_amount_consumed with 32608 nan values
# Dropping pm_lifestyle_change_how with 32608 nan values
# Dropping pm_lifestyle_change with 32608 nan values
# Dropping pm_health with 32608 nan values
# Dropping pm_gender with 32608 nan values
# Dropping pm_gastro_problems_unspecified with 32608 nan values
# Dropping pm_gastro_problems_other with 32608 nan values
# Dropping pm_gastro_problems_irritable_bowel_syndrome_ibs with 32608 nan values
# Dropping pm_gastro_problems_i_have_had_surgery_on_my_intestines with 32608 nan values
# Dropping pm_gastro_problems_gastrointestinal_cancer with 32608 nan values
# Dropping pm_gastro_problems_frequent_more_than_once_a_week_diarrhea with 32608 nan values
# Dropping pm_gastro_problems_frequent_more_than_once_a_week_constipation with 32608 nan values
# Dropping pm_gastro_problems_crohns_disease_or_ulcerative_colitis with 32608 nan values
# Dropping pm_gastro_problems with 32608 nan values
# Dropping pm_experience_worth_it with 32608 nan values
# Dropping pm_ethnicity with 32608 nan values
# Dropping pm_email with 32608 nan values
# Dropping pm_education with 32608 nan values
# Dropping pm_concern with 32608 nan values
# Dropping pm_age with 32608 nan values
# Dropping plant_protein_frequency with 29148 nan values
# Dropping physical_specimen_location with only one unique value
# Dropping other_animals_free_text with 32608 nan values
# Dropping oils_frequency_soy with 32608 nan values
# Dropping oils_frequency_oxalate with 32608 nan values
# Dropping name with 32608 nan values
# Dropping lowgrain_diet_type with 25347 nan values
# Dropping longitude with 29172 nan values
# Dropping living_status with 32590 nan values
# Dropping latitude with 29172 nan values
# Dropping keep_sample_for_thdmi with 30422 nan values
# Dropping ibd_diagnosis_refined with 31715 nan values
# Dropping ibd_diagnosis with 32601 nan values
# Dropping humans_free_text with 32608 nan values
# Dropping hours_outside with 32589 nan values
# Dropping host_weight_units with only one unique value
# Dropping host_taxid with only one unique value
# Dropping host_scientific_name with 32596 nan values
# Dropping host_height_units with only one unique value
# Dropping host_common_name with only one unique value
# Dropping host_age_units with only one unique value
# Dropping height_units with 32608 nan values
# Dropping height_cm with 32608 nan values
# Dropping geo_loc_name with 29169 nan values
# Dropping food_type with 32590 nan values
# Dropping food_special_unspecified with 29295 nan values
# Dropping food_special_organic with 29295 nan values
# Dropping food_special_grain_free with 29295 nan values
# Dropping food_special with 32608 nan values
# Dropping food_source_wild_food with 29295 nan values
# Dropping food_source_unspecified with 29295 nan values
# Dropping food_source_pet_store_food with 29295 nan values
# Dropping food_source_human_food with 29295 nan values
# Dropping food_source with 32608 nan values
# Dropping fermented_produce_personal_other_1 with 32202 nan values
# Dropping fermented_produce_personal_other with 32608 nan values
# Dropping fermented_produce_personal_fish_sauce with only one unique value
# Dropping fermented_produce_personal with 32608 nan values
# Dropping fermented_produce_commercial_tempeh with only one unique value
# Dropping fermented_produce_commercial_other_1 with 32202 nan values
# Dropping fermented_produce_commercial_other with 32608 nan values
# Dropping fermented_produce_commercial_kombucha with only one unique value
# Dropping fermented_produce_commercial_kefir_water with only one unique value
# Dropping fermented_produce_commercial_fish_sauce with only one unique value
# Dropping fermented_produce_commercial_fermented_tofu with only one unique value
# Dropping fermented_produce_commercial_fermented_beansmisonatto with only one unique value
# Dropping fermented_produce_commercial_cottage_cheese with only one unique value
# Dropping fermented_produce_commercial_chicha with only one unique value
# Dropping fermented_produce_commercial with 32608 nan values
# Dropping fermented_other with 32608 nan values
# Dropping fermented_increased with 31545 nan values
# Dropping fermented_frequency with 31507 nan values
# Dropping fermented_consumed_other_1 with 32202 nan values
# Dropping fermented_consumed_other with 32608 nan values
# Dropping fermented_consumed with 32608 nan values
# Dropping elevation with 29448 nan values
# Dropping economic_region with 32601 nan values
# Dropping diet with 32590 nan values
# Dropping diabetes_type with 32026 nan values
# Dropping depression_bipolar_schizophrenia with 28177 nan values
# Dropping dark_mode_on with 32608 nan values
# Dropping covid_worrying with 29050 nan values
# Dropping covid_worried_sleep with 29061 nan values
# Dropping covid_waking_up_early with 29174 nan values
# Dropping covid_symptoms_stay_home with 31066 nan values
# Dropping covid_symptoms_other with 32608 nan values
# Dropping covid_suspected_positive_date with 32608 nan values
# Dropping covid_suspected_positive with 29129 nan values
# Dropping covid_sleep_pattern with 29026 nan values
# Dropping covid_sleep_interference with 29088 nan values
# Dropping covid_rideshare with 29076 nan values
# Dropping covid_quality_of_life with 29093 nan values
# Dropping covid_patient_care_seven_days_confirmed with 31593 nan values
# Dropping covid_patient_care_seven_days with 31469 nan values
# Dropping covid_patient_care_ppe with 32325 nan values
# Dropping covid_patient_care with 29034 nan values
# Dropping covid_occupation with 32608 nan values
# Dropping covid_level_of_wellbeing with 29044 nan values
# Dropping covid_left_home with 29049 nan values
# Dropping covid_interest_pleasure with 29053 nan values
# Dropping covid_difficulty_staying_asleep with 29170 nan values
# Dropping covid_difficulty_falling_asleep with 29147 nan values
# Dropping covid_depressed with 29053 nan values
# Dropping covid_anxious with 29046 nan values
# Dropping country with 32543 nan values
# Dropping coprophage with 32590 nan values
# Dropping census_region with 32586 nan values
# Dropping cancer_treatment with 31048 nan values
# Dropping body_site with 32608 nan values
# Dropping body_product with 32608 nan values
# Dropping bmi with 32608 nan values
# Dropping beet_frequency with 29181 nan values
# Dropping atypical_sleep_time with 32608 nan values
# Dropping artificial_sweeteners_food with 32608 nan values
# Dropping artificial_gi_disorders with 32608 nan values
# Dropping artificial_gi_disorder_types_unspecified with 32332 nan values
# Dropping artificial_gi_disorder_types_stomachache with 32332 nan values
# Dropping artificial_gi_disorder_types_soft_stools with 32332 nan values
# Dropping artificial_gi_disorder_types_diarrhea with 32332 nan values
# Dropping artificial_gi_disorder_types_constipation with 32332 nan values
# Dropping animal_type_free_text with 32608 nan values
# Dropping animal_type with 32589 nan values
# Dropping animal_origin with 32590 nan values
# Dropping animal_gender with 32590 nan values
# Dropping animal_free_text with 32608 nan values
# Dropping animal_age with 32590 nan values
# Dropping age_years with 32596 nan values

# %%
import plotly.express as px
from ipywidgets.embed import embed_minimal_html

obsm_matrices = list(adata.obsm.keys())
# obsm_matrices = ["euc_mix_2", "geomstats_hyperboloid_mix_CONVERTED_2", "hyp_mix_2_PAC", "pca_2"]
metadata_vars = list(adata.obs.keys())
# component_vars = list(adata.varm.keys())
# component_vars.append(None)
component_vars = [
    "component_embeddings_euclidean_2",
    "component_embeddings_poincare_2",
    None,
]

# Create two blank figures, one for NaN values and one for regular data
# This has colorbar set to None so that it doesn't show up
pdisk = go.Scattergl(
    x=[],
    y=[],
    mode="lines",
    line=dict(color="black"),
    name="Poincare disk boundary",
)
scatter_nan = go.Scattergl(
    x=[],
    y=[],
    mode="markers",
    text=[],
    marker=dict(color="gray", colorbar=None, size=4),
    name="NaN values",
)
scatter = go.Scattergl(
    x=[],
    y=[],
    mode="markers",
    text=[],
    marker=dict(color=[], colorscale="Plasma", size=4, colorbar=dict(title="")),
    name="Valid values",
)
scatter_components = go.Scattergl(
    x=[],
    y=[],
    mode="markers",
    text=[],
    marker=dict(
        color=[], colorscale="Viridis", size=4, colorbar=dict(title="")
    ),
    name="OTUs",
)

fig = go.FigureWidget(
    data=[scatter_nan, scatter, pdisk, scatter_components],
    layout=go.Layout(
        title=dict(text="Plotting Embeddings"),
        xaxis=dict(title="X"),
        yaxis=dict(title="Y"),
        hovermode="closest",
        # Move legend to bottom right
        legend=dict(x=1.1, y=0.5, bgcolor="rgba(0,0,0,0)"),
        autosize=False,
        width=1000,
        height=1000,
    ),
)

# Create widgets: select embedding and metadata, click plot
embed_dropdown = widgets.Dropdown(
    options=obsm_matrices, value=obsm_matrices[0], description="Embedding:"
)
metadata_dropdown = widgets.Dropdown(
    options=metadata_vars, value=metadata_vars[0], description="Metadata:"
)
component_dropdown = widgets.Dropdown(
    options=component_vars, value=None, description="OTU embeddings:"
)
dim1_textbox = widgets.Text(value="0", description="Dim 1:", disabled=False)
dim2_textbox = widgets.Text(value="1", description="Dim 2:", disabled=False)
plot_button = widgets.Button(description="Plot")

# Function to find nans in metadata
def find_nans(col):
    mask1 = col.isin(nan_vals)
    mask2 = col.isnull()
    return mask1 | mask2


# For Poincare disk
t = np.linspace(0, 2 * np.pi, 100)
circle_x = np.cos(t)
circle_y = np.sin(t)

# Update function: change embeddings, color, text
def plot_on_click(b):
    embedding = embed_dropdown.value
    dim1 = int(dim1_textbox.value)
    dim2 = int(dim2_textbox.value)
    x = adata.obsm[embedding][:, dim1]
    y = adata.obsm[embedding][:, dim2]
    if embedding in ["h2", "poi_mix_2"]:
        fig.data[2].x = circle_x
        fig.data[2].y = circle_y
    else:
        fig.data[2].x = []
        fig.data[2].y = []

    # Add color based on metadata
    metadata = metadata_dropdown.value
    col = adata.obs[metadata]
    if adata.obs[metadata].dtype.name == "category":
        col = col.str.lower()
        col = col.astype("category")
        color = col.cat.codes.copy()
    else:
        color = col.copy()

    nan_mask = find_nans(col)
    fig.data[0].x = x[nan_mask]
    fig.data[0].y = y[nan_mask]
    fig.data[1].marker.color = color[~nan_mask]
    fig.data[1].marker.colorbar.title = metadata
    fig.data[1].marker.colorbar.titleside = "top"
    fig.data[1].x = x[~nan_mask]
    fig.data[1].y = y[~nan_mask]

    # Update text to include metadata
    fig.data[0].text = [
        f"Index: {i}<br>{metadata}: {j}"
        for i, j in zip(adata.obs.index[nan_mask], col[nan_mask])
    ]
    fig.data[1].text = [
        f"Index: {i}<br>{metadata}: {j}"
        for i, j in zip(adata.obs.index[~nan_mask], col[~nan_mask])
    ]

    # Add component embeddings
    if component_dropdown.value is not None:
        ce = adata.varm[component_dropdown.value]
        if isinstance(ce, pd.DataFrame):
            ce = ce.values
        ce_x = ce[:, dim1]
        ce_y = ce[:, dim2]
        fig.data[3].x = ce_x
        fig.data[3].y = ce_y
        fig.data[3].text = [
            f"{i}<br>{' '.join(adata.var.loc[i])}" for i in adata.var.index
        ]
        fig.data[3].marker.color = (
            adata.var["taxonomy_1"].astype("category").cat.codes
        )
    else:
        fig.data[3].x = []
        fig.data[3].y = []
        fig.data[3].text = []
        fig.data[3].marker.color = []


plot_button.on_click(plot_on_click)

vbox = widgets.VBox(
    [
        embed_dropdown,
        metadata_dropdown,
        component_dropdown,
        dim1_textbox,
        dim2_textbox,
        plot_button,
    ]
)
vbox_all = widgets.VBox([vbox, fig])
display(vbox_all)

# Save plot 
# embed_minimal_html("plot.html", views=[vbox_all], title="Mixture embeddings AGP")
# Out:
# VBox(children=(VBox(children=(Dropdown(description='Embedding:', options=('euc_mix_128', 'euc_mix_16', 'euc_mi…

# %%
adata.obs["host_body_habitat"].groupby(adata.obs["host_body_habitat"]).count()
# Out:
# host_body_habitat
# UBERON:feces            284
# nan                    3214
# uberon:blood              3
# uberon:ear               55
# uberon:eye               54
# uberon:feces          24873
# uberon:hair              19
# uberon:nose             297
# uberon:oral cavity     2259
# uberon:skin            1405
# uberon:vagina           145
# Name: host_body_habitat, dtype: int64

# %%
# For offline troubleshooting

np.savetxt(
    "data/2d_hyperboloid_mix.csv",
    adata.obsm["geomstats_hyperboloid_mix_CONVERTED_2_100iter"],
)
adata.obs.to_csv("data/2d_hyperboloid_mix_metadata.csv")
